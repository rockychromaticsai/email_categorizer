# %%
# !sudo apt-get install python3.9
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpython3.9-minimal libpython3.9-stdlib python3.9-minimal
# Suggested packages:
#   python3.9-venv binfmt-support
# The following NEW packages will be installed:
#   libpython3.9-minimal libpython3.9-stdlib python3.9 python3.9-minimal
# 0 upgraded, 4 newly installed, 0 to remove and 38 not upgraded.
# Need to get 4,847 kB of archives.
# After this operation, 18.9 MB of additional disk space will be used.
# Get:1 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.9-minimal amd64 3.9.23-1+jammy1 [837 kB]
# Get:2 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.9-minimal amd64 3.9.23-1+jammy1 [2,075 kB]
# Get:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.9-stdlib amd64 3.9.23-1+jammy1 [1,842 kB]
# Get:4 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.9 amd64 3.9.23-1+jammy1 [93.1 kB]
# Fetched 4,847 kB in 13s (382 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 4.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libpython3.9-minimal:amd64.
# (Reading database ... 126675 files and directories currently installed.)
# Preparing to unpack .../libpython3.9-minimal_3.9.23-1+jammy1_amd64.deb ...
# Unpacking libpython3.9-minimal:amd64 (3.9.23-1+jammy1) ...
# Selecting previously unselected package python3.9-minimal.
# Preparing to unpack .../python3.9-minimal_3.9.23-1+jammy1_amd64.deb ...
# Unpacking python3.9-minimal (3.9.23-1+jammy1) ...
# Selecting previously unselected package libpython3.9-stdlib:amd64.
# Preparing to unpack .../libpython3.9-stdlib_3.9.23-1+jammy1_amd64.deb ...
# Unpacking libpython3.9-stdlib:amd64 (3.9.23-1+jammy1) ...
# Selecting previously unselected package python3.9.
# Preparing to unpack .../python3.9_3.9.23-1+jammy1_amd64.deb ...
# Unpacking python3.9 (3.9.23-1+jammy1) ...
# Setting up libpython3.9-minimal:amd64 (3.9.23-1+jammy1) ...
# Setting up python3.9-minimal (3.9.23-1+jammy1) ...
# Setting up libpython3.9-stdlib:amd64 (3.9.23-1+jammy1) ...
# Setting up python3.9 (3.9.23-1+jammy1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py39_23.3.1-0-Linux-x86_64.sh

# !chmod +x Miniconda3-py39_23.3.1-0-Linux-x86_64.sh

# !./Miniconda3-py39_23.3.1-0-Linux-x86_64.sh -b -f -p /usr/local

# !conda update conda
# Out:
# --2025-10-10 05:58:52--  https://repo.anaconda.com/miniconda/Miniconda3-py39_23.3.1-0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70605094 (67M) [application/x-sh]
# Saving to: ‘Miniconda3-py39_23.3.1-0-Linux-x86_64.sh.2’
#
# Miniconda3-py39_23. 100%[===================>]  67.33M   292MB/s    in 0.2s
#
# 2025-10-10 05:58:53 (292 MB/s) - ‘Miniconda3-py39_23.3.1-0-Linux-x86_64.sh.2’ saved [70605094/70605094]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
#
# Downloading and Extracting Packages
#
#
# Downloading and Extracting Packages
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 25.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=25.9.0
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boltons-25.0.0             |   py39h06a4308_0         426 KB
#     brotlicffi-1.0.9.2         |   py39h6a678d5_1         365 KB
#     bzip2-1.0.8                |       h5eee18b_6         262 KB
#     ca-certificates-2025.9.9   |       h06a4308_0         127 KB
#     certifi-2025.10.5          |   py39h06a4308_0         157 KB
#     cffi-1.17.1                |   py39h1fdaa30_1         249 KB
#     charset-normalizer-3.3.2   |     pyhd3eb1b0_0          44 KB
#     conda-package-handling-2.4.0|   py39h06a4308_0         272 KB
#     conda-package-streaming-0.12.0|   py39h06a4308_0          32 KB
#     cryptography-44.0.1        |   py39h7825ff9_0         1.5 MB
#     expat-2.7.1                |       h6a678d5_0         182 KB
#     idna-3.7                   |   py39h06a4308_0         113 KB
#     jsonpatch-1.33             |   py39h06a4308_1          31 KB
#     jsonpointer-3.0.0          |   py39h06a4308_0          19 KB
#     ld_impl_linux-64-2.44      |       h153f514_2         672 KB
#     libffi-3.4.4               |       h6a678d5_1         141 KB
#     libxcb-1.17.0              |       h9b100fa_0         430 KB
#     libzlib-1.3.1              |       hb25bd0a_0          59 KB
#     lz4-c-1.9.4                |       h6a678d5_1         156 KB
#     ncurses-6.5                |       h7934f7d_0         1.1 MB
#     openssl-3.0.18             |       hd6dcaed_0         4.5 MB
#     packaging-25.0             |   py39h06a4308_0         172 KB
#     pluggy-1.5.0               |   py39h06a4308_0          37 KB
#     pthread-stubs-0.3          |       h0ce48e5_1           5 KB
#     pycosat-0.6.6              |   py39h5eee18b_2          88 KB
#     pycparser-2.23             |   py39h06a4308_0         224 KB
#     pyopenssl-25.0.0           |   py39h06a4308_0          92 KB
#     python-3.9.23              |       he99959a_0        24.7 MB
#     readline-8.3               |       hc2a1206_0         471 KB
#     requests-2.32.5            |   py39h06a4308_0         149 KB
#     ruamel.yaml.clib-0.2.12    |   py39h5eee18b_0         159 KB
#     six-1.17.0                 |   py39h06a4308_0          31 KB
#     sqlite-3.50.2              |       hb25bd0a_1         1.1 MB
#     tk-8.6.15                  |       h54e0aa7_0         3.4 MB
#     toolz-1.0.0                |   py39h06a4308_0         106 KB
#     tqdm-4.67.1                |   py39h2f386ee_0         133 KB
#     typing_extensions-4.15.0   |   py39h06a4308_0          79 KB
#     tzdata-2025b               |       h04d1e81_0         116 KB
#     urllib3-2.5.0              |   py39h06a4308_0         305 KB
#     xorg-libx11-1.8.12         |       h9b100fa_1         895 KB
#     xorg-libxau-1.0.12         |       h9b100fa_0          13 KB
#     xorg-libxdmcp-1.1.5        |       h9b100fa_0          19 KB
#     xorg-xorgproto-2024.1      |       h5eee18b_1         580 KB
#     xz-5.6.4                   |       h5eee18b_1         567 KB
#     zlib-1.3.1                 |       hb25bd0a_0          96 KB
#     zstandard-0.24.0           |   py39h3d778a8_0         396 KB
#     zstd-1.5.7                 |       h11fc155_0         608 KB
#     ------------------------------------------------------------
#                                            Total:        45.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotlicffi         pkgs/main/linux-64::brotlicffi-1.0.9.2-py39h6a678d5_1
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h5eee18b_6
#   expat              pkgs/main/linux-64::expat-2.7.1-h6a678d5_0
#   libxcb             pkgs/main/linux-64::libxcb-1.17.0-h9b100fa_0
#   libzlib            pkgs/main/linux-64::libzlib-1.3.1-hb25bd0a_0
#   lz4-c              pkgs/main/linux-64::lz4-c-1.9.4-h6a678d5_1
#   pthread-stubs      pkgs/main/linux-64::pthread-stubs-0.3-h0ce48e5_1
#   typing_extensions  pkgs/main/linux-64::typing_extensions-4.15.0-py39h06a4308_0
#   xorg-libx11        pkgs/main/linux-64::xorg-libx11-1.8.12-h9b100fa_1
#   xorg-libxau        pkgs/main/linux-64::xorg-libxau-1.0.12-h9b100fa_0
#   xorg-libxdmcp      pkgs/main/linux-64::xorg-libxdmcp-1.1.5-h9b100fa_0
#   xorg-xorgproto     pkgs/main/linux-64::xorg-xorgproto-2024.1-h5eee18b_1
#   zstd               pkgs/main/linux-64::zstd-1.5.7-h11fc155_0
#
# The following packages will be REMOVED:
#
#   brotlipy-0.7.0-py39h27cfd23_1003
#
# The following packages will be UPDATED:
#
#   boltons                             23.0.0-py39h06a4308_0 --> 25.0.0-py39h06a4308_0
#   ca-certificates                     2023.01.10-h06a4308_0 --> 2025.9.9-h06a4308_0
#   certifi                          2022.12.7-py39h06a4308_0 --> 2025.10.5-py39h06a4308_0
#   cffi                                1.15.1-py39h5eee18b_3 --> 1.17.1-py39h1fdaa30_1
#   charset-normalizer                     2.0.4-pyhd3eb1b0_0 --> 3.3.2-pyhd3eb1b0_0
#   conda-package-han~                   2.0.2-py39h06a4308_0 --> 2.4.0-py39h06a4308_0
#   conda-package-str~                   0.7.0-py39h06a4308_0 --> 0.12.0-py39h06a4308_0
#   cryptography                        39.0.1-py39h9ce1e76_0 --> 44.0.1-py39h7825ff9_0
#   idna                                   3.4-py39h06a4308_0 --> 3.7-py39h06a4308_0
#   jsonpatch          pkgs/main/noarch::jsonpatch-1.32-pyhd~ --> pkgs/main/linux-64::jsonpatch-1.33-py39h06a4308_1
#   jsonpointer        pkgs/main/noarch::jsonpointer-2.1-pyh~ --> pkgs/main/linux-64::jsonpointer-3.0.0-py39h06a4308_0
#   ld_impl_linux-64                          2.38-h1181459_1 --> 2.44-h153f514_2
#   libffi                                   3.4.2-h6a678d5_6 --> 3.4.4-h6a678d5_1
#   ncurses                                    6.4-h6a678d5_0 --> 6.5-h7934f7d_0
#   openssl                                 1.1.1t-h7f8727e_0 --> 3.0.18-hd6dcaed_0
#   packaging                             23.0-py39h06a4308_0 --> 25.0-py39h06a4308_0
#   pluggy                               1.0.0-py39h06a4308_1 --> 1.5.0-py39h06a4308_0
#   pycosat                              0.6.4-py39h5eee18b_0 --> 0.6.6-py39h5eee18b_2
#   pycparser          pkgs/main/noarch::pycparser-2.21-pyhd~ --> pkgs/main/linux-64::pycparser-2.23-py39h06a4308_0
#   pyopenssl                           23.0.0-py39h06a4308_0 --> 25.0.0-py39h06a4308_0
#   python                                  3.9.16-h7a1cb2a_2 --> 3.9.23-he99959a_0
#   readline                                   8.2-h5eee18b_0 --> 8.3-hc2a1206_0
#   requests                            2.28.1-py39h06a4308_1 --> 2.32.5-py39h06a4308_0
#   ruamel.yaml.clib                     0.2.6-py39h5eee18b_1 --> 0.2.12-py39h5eee18b_0
#   six                pkgs/main/noarch::six-1.16.0-pyhd3eb1~ --> pkgs/main/linux-64::six-1.17.0-py39h06a4308_0
#   sqlite                                  3.41.1-h5eee18b_0 --> 3.50.2-hb25bd0a_1
#   tk                                      8.6.12-h1ccaba5_0 --> 8.6.15-h54e0aa7_0
#   toolz                               0.12.0-py39h06a4308_0 --> 1.0.0-py39h06a4308_0
#   tqdm                                4.65.0-py39hb070fc8_0 --> 4.67.1-py39h2f386ee_0
#   tzdata                                   2023c-h04d1e81_0 --> 2025b-h04d1e81_0
#   urllib3                            1.26.15-py39h06a4308_0 --> 2.5.0-py39h06a4308_0
#   xz                                      5.2.10-h5eee18b_1 --> 5.6.4-h5eee18b_1
#   zlib                                    1.2.13-h5eee18b_0 --> 1.3.1-hb25bd0a_0
#   zstandard                           0.19.0-py39h5eee18b_0 --> 0.24.0-py39h3d778a8_0
#
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# zstandard-0.24.0     | 396 KB    | :   0% 0/1 [00:00<?, ?it/s]
# zlib-1.3.1           | 96 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
# packaging-25.0       | 172 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# six-1.17.0           | 31 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# openssl-3.0.18       | 4.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# pycosat-0.6.6        | 88 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# certifi-2025.10.5    | 157 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# xorg-libxau-1.0.12   | 13 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# boltons-25.0.0       | 426 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 59 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# pthread-stubs-0.3    | 5 KB      | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 430 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 116 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# jsonpointer-3.0.0    | 19 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxdmcp-1.1.5  | 19 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idna-3.7             | 113 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 79 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 672 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.15            | 3.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstandard-0.24.0     | 396 KB    | :   4% 0.040413209278462404/1 [00:00<00:02,  2.97s/it]
#
#
#
# openssl-3.0.18       | 4.5 MB    | :   0% 0.003483453807029756/1 [00:00<00:31, 31.76s/it]
#
#
# six-1.17.0           | 31 KB     | :  52% 0.5243718995039206/1 [00:00<00:00,  4.48it/s]
# zlib-1.3.1           | 96 KB     | :  17% 0.16692817116658176/1 [00:00<00:00,  1.32it/s]
#
# packaging-25.0       | 172 KB    | :   9% 0.09328330590934712/1 [00:00<00:01,  1.46s/it]
#
#
#
#
# pycosat-0.6.6        | 88 KB     | :  18% 0.1814436643115019/1 [00:00<00:00,  1.17it/s]
#
#
# six-1.17.0           | 31 KB     | : 100% 1.0/1 [00:00<00:00,  4.48it/s]
#
#
#
#
#
# certifi-2025.10.5    | 157 KB    | :  10% 0.10197108412738917/1 [00:00<00:01,  1.81s/it]
#
#
#
#
#
#
# xorg-libxau-1.0.12   | 13 KB     | : 100% 1.0/1 [00:00<00:00,  5.34it/s]
#
#
#
# zstandard-0.24.0     | 396 KB    | : 100% 1.0/1 [00:00<00:00,  4.97it/s]
#
#
#
#
#
#
#
# boltons-25.0.0       | 426 KB    | :   4% 0.037541301389009823/1 [00:00<00:05,  6.07s/it]
#
#
#
#
#
#
#
#
#
# pthread-stubs-0.3    | 5 KB      | : 100% 1.0/1 [00:00<00:00,  4.38it/s]
# zlib-1.3.1           | 96 KB     | : 100% 1.0/1 [00:00<00:00,  3.97it/s]
# zlib-1.3.1           | 96 KB     | : 100% 1.0/1 [00:00<00:00,  3.97it/s]
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 59 KB     | :  27% 0.2699309685816432/1 [00:00<00:00,  1.07it/s]
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 430 KB    | :   4% 0.03717806167600808/1 [00:00<00:06,  7.00s/it]
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 116 KB    | :  14% 0.13742430088406501/1 [00:00<00:01,  2.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# jsonpointer-3.0.0    | 19 KB     | :  85% 0.8461935750439005/1 [00:00<00:00,  2.80it/s]
#
#
#
#
# pycosat-0.6.6        | 88 KB     | : 100% 1.0/1 [00:00<00:00,  3.44it/s]
#
#
#
#
# pycosat-0.6.6        | 88 KB     | : 100% 1.0/1 [00:00<00:00,  3.44it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxdmcp-1.1.5  | 19 KB     | :  85% 0.85067497403946/1 [00:00<00:00,  2.67it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idna-3.7             | 113 KB    | :  14% 0.1415623352946767/1 [00:00<00:02,  2.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 79 KB     | :  20% 0.20159216467953686/1 [00:00<00:01,  1.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.15            | 3.4 MB    | :   0% 0.00453827661272385/1 [00:00<01:15, 76.27s/it]
#
# packaging-25.0       | 172 KB    | : 100% 1.0/1 [00:00<00:00,  2.83it/s]
#
# packaging-25.0       | 172 KB    | : 100% 1.0/1 [00:00<00:00,  2.83it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 672 KB    | :   2% 0.02380578754961961/1 [00:00<00:14, 14.84s/it]
#
#
#
#
#
# certifi-2025.10.5    | 157 KB    | : 100% 1.0/1 [00:00<00:00,  3.06it/s]
#
#
#
#
#
# certifi-2025.10.5    | 157 KB    | : 100% 1.0/1 [00:00<00:00,  3.06it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# xorg-libxau-1.0.12   | 13 KB     | : 100% 1.0/1 [00:00<00:00,  5.34it/s]
#
#
#
#
#
#
#
#
#
# pthread-stubs-0.3    | 5 KB      | : 100% 1.0/1 [00:00<00:00,  4.38it/s]
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 59 KB     | : 100% 1.0/1 [00:00<00:00,  2.47it/s]
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 59 KB     | : 100% 1.0/1 [00:00<00:00,  2.47it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.15            | 3.4 MB    | :  77% 0.7669687475503306/1 [00:00<00:00,  2.22it/s]
#
#
#
#
#
#
#
# boltons-25.0.0       | 426 KB    | : 100% 1.0/1 [00:00<00:00,  1.64it/s]
#
#
#
#
#
#
#
# boltons-25.0.0       | 426 KB    | : 100% 1.0/1 [00:00<00:00,  1.64it/s]
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 430 KB    | : 100% 1.0/1 [00:00<00:00,  1.65it/s]
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 430 KB    | : 100% 1.0/1 [00:00<00:00,  1.65it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# jsonpointer-3.0.0    | 19 KB     | : 100% 1.0/1 [00:00<00:00,  2.80it/s]
#
#
#
# openssl-3.0.18       | 4.5 MB    | : 100% 1.0/1 [00:01<00:00,  1.24s/it]
#
#
#
# openssl-3.0.18       | 4.5 MB    | : 100% 1.0/1 [00:01<00:00,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxdmcp-1.1.5  | 19 KB     | : 100% 1.0/1 [00:01<00:00,  2.67it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idna-3.7             | 113 KB    | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# idna-3.7             | 113 KB    | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 79 KB     | : 100% 1.0/1 [00:01<00:00,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 79 KB     | : 100% 1.0/1 [00:01<00:00,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 116 KB    | : 100% 1.0/1 [00:01<00:00,  1.33s/it]
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 116 KB    | : 100% 1.0/1 [00:01<00:00,  1.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 672 KB    | : 100% 1.0/1 [00:01<00:00,  1.32s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 672 KB    | : 100% 1.0/1 [00:01<00:00,  1.32s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.15            | 3.4 MB    | : 100% 1.0/1 [00:02<00:00,  2.22it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
import sys

sys.path.append('/usr/local/lib/python3.9/site-packages')

# !conda create -n myenv python=3.9
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 25.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=25.9.0
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/myenv
#
#   added / updated specs:
#     - python=3.9
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pip-25.2                   |     pyhc872135_0         1.2 MB
#     setuptools-80.9.0          |   py39h06a4308_0         1.4 MB
#     wheel-0.45.1               |   py39h06a4308_0         114 KB
#     ------------------------------------------------------------
#                                            Total:         2.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h5eee18b_6
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2025.9.9-h06a4308_0
#   expat              pkgs/main/linux-64::expat-2.7.1-h6a678d5_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.44-h153f514_2
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_1
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-11.2.0-h1234567_1
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-11.2.0-h1234567_1
#   libxcb             pkgs/main/linux-64::libxcb-1.17.0-h9b100fa_0
#   libzlib            pkgs/main/linux-64::libzlib-1.3.1-hb25bd0a_0
#   ncurses            pkgs/main/linux-64::ncurses-6.5-h7934f7d_0
#   openssl            pkgs/main/linux-64::openssl-3.0.18-hd6dcaed_0
#   pip                pkgs/main/noarch::pip-25.2-pyhc872135_0
#   pthread-stubs      pkgs/main/linux-64::pthread-stubs-0.3-h0ce48e5_1
#   python             pkgs/main/linux-64::python-3.9.23-he99959a_0
#   readline           pkgs/main/linux-64::readline-8.3-hc2a1206_0
#   setuptools         pkgs/main/linux-64::setuptools-80.9.0-py39h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.50.2-hb25bd0a_1
#   tk                 pkgs/main/linux-64::tk-8.6.15-h54e0aa7_0
#   tzdata             pkgs/main/noarch::tzdata-2025b-h04d1e81_0
#   wheel              pkgs/main/linux-64::wheel-0.45.1-py39h06a4308_0
#   xorg-libx11        pkgs/main/linux-64::xorg-libx11-1.8.12-h9b100fa_1
#   xorg-libxau        pkgs/main/linux-64::xorg-libxau-1.0.12-h9b100fa_0
#   xorg-libxdmcp      pkgs/main/linux-64::xorg-libxdmcp-1.1.5-h9b100fa_0
#   xorg-xorgproto     pkgs/main/linux-64::xorg-xorgproto-2024.1-h5eee18b_1
#   xz                 pkgs/main/linux-64::xz-5.6.4-h5eee18b_1
#   zlib               pkgs/main/linux-64::zlib-1.3.1-hb25bd0a_0
#
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# wheel-0.45.1         | 114 KB    | :   0% 0/1 [00:00<?, ?it/s]
# pip-25.2             | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# setuptools-80.9.0    | 1.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
# pip-25.2             | 1.2 MB    | :   1% 0.012942774986570607/1 [00:00<00:09, 10.06s/it]
#
# wheel-0.45.1         | 114 KB    | :  14% 0.14068349647947792/1 [00:00<00:01,  1.31s/it]
# pip-25.2             | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  2.19it/s]
# wheel-0.45.1         | 114 KB    | : 100% 1.0/1 [00:00<00:00,  1.89it/s]
#
# setuptools-80.9.0    | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  1.42it/s]
#
#
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate myenv
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# %%shell
#
# eval "$(conda shell.bash hook)"
#
# conda activate myenv
#
# pip install tflite-model-maker
#
#
# # Imports and check that we are using TF2.x
# import numpy as np
# import os
#
# from tflite_model_maker import configs
# from tflite_model_maker import ExportFormat
# from tflite_model_maker import model_spec
# from tflite_model_maker import text_classifier
# from tflite_model_maker.text_classifier import DataLoader
#
# import tensorflow as tf
# assert tf.__version__.startswith('2')
# tf.get_logger().setLevel('ERROR')
# Out:
# Requirement already satisfied: tflite-model-maker in /usr/local/envs/myenv/lib/python3.9/site-packages (0.4.3)
# Requirement already satisfied: tf-models-official==2.3.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (2.3.0)
# Requirement already satisfied: numpy<1.23.4,>=1.17.3 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (1.23.3)
# Requirement already satisfied: pillow>=7.0.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (11.3.0)
# Requirement already satisfied: sentencepiece>=0.1.91 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (0.2.1)
# Requirement already satisfied: tensorflow-datasets>=2.1.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (4.9.0)
# Requirement already satisfied: fire>=0.3.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (0.7.1)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (25.9.23)
# Requirement already satisfied: absl-py>=0.10.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (1.4.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (1.25.11)
# Requirement already satisfied: tflite-support>=0.4.2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (0.4.4)
# Requirement already satisfied: tensorflowjs<3.19.0,>=2.4.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (3.18.0)
# Requirement already satisfied: tensorflow>=2.6.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (2.8.4)
# Requirement already satisfied: numba>=0.53 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (0.60.0)
# Requirement already satisfied: librosa==0.8.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (0.8.1)
# Requirement already satisfied: lxml>=4.6.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (6.0.2)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (6.0.3)
# Requirement already satisfied: matplotlib<3.5.0,>=3.0.3 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (3.4.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (1.17.0)
# Requirement already satisfied: tensorflow-addons>=0.11.2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (0.23.0)
# Requirement already satisfied: neural-structured-learning>=1.3.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (1.4.0)
# Requirement already satisfied: tensorflow-model-optimization>=0.5 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (0.8.0)
# Requirement already satisfied: Cython>=0.29.13 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (3.1.4)
# Requirement already satisfied: scann==1.2.6 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (1.2.6)
# Requirement already satisfied: tensorflow-hub<0.13,>=0.7.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-model-maker) (0.12.0)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from librosa==0.8.1->tflite-model-maker) (3.0.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from librosa==0.8.1->tflite-model-maker) (1.13.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from librosa==0.8.1->tflite-model-maker) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/envs/myenv/lib/python3.9/site-packages (from librosa==0.8.1->tflite-model-maker) (1.5.2)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from librosa==0.8.1->tflite-model-maker) (5.2.1)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from librosa==0.8.1->tflite-model-maker) (0.4.3)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from librosa==0.8.1->tflite-model-maker) (0.13.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from librosa==0.8.1->tflite-model-maker) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from librosa==0.8.1->tflite-model-maker) (20.9)
# Requirement already satisfied: dataclasses in /usr/local/envs/myenv/lib/python3.9/site-packages (from tf-models-official==2.3.0->tflite-model-maker) (0.6)
# Requirement already satisfied: gin-config in /usr/local/envs/myenv/lib/python3.9/site-packages (from tf-models-official==2.3.0->tflite-model-maker) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tf-models-official==2.3.0->tflite-model-maker) (2.184.0)
# Requirement already satisfied: google-cloud-bigquery>=0.31.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tf-models-official==2.3.0->tflite-model-maker) (3.30.0)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tf-models-official==2.3.0->tflite-model-maker) (1.7.4.5)
# Requirement already satisfied: opencv-python-headless in /usr/local/envs/myenv/lib/python3.9/site-packages (from tf-models-official==2.3.0->tflite-model-maker) (4.11.0.86)
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tf-models-official==2.3.0->tflite-model-maker) (2.3.3)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tf-models-official==2.3.0->tflite-model-maker) (7.1.0)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tf-models-official==2.3.0->tflite-model-maker) (9.0.0)
# Requirement already satisfied: tf-slim>=1.1.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tf-models-official==2.3.0->tflite-model-maker) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/envs/myenv/lib/python3.9/site-packages (from matplotlib<3.5.0,>=3.0.3->tflite-model-maker) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from matplotlib<3.5.0,>=3.0.3->tflite-model-maker) (1.4.7)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from matplotlib<3.5.0,>=3.0.3->tflite-model-maker) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/envs/myenv/lib/python3.9/site-packages (from matplotlib<3.5.0,>=3.0.3->tflite-model-maker) (2.9.0.post0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow>=2.6.0->tflite-model-maker) (1.6.3)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow>=2.6.0->tflite-model-maker) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow>=2.6.0->tflite-model-maker) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow>=2.6.0->tflite-model-maker) (3.14.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow>=2.6.0->tflite-model-maker) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow>=2.6.0->tflite-model-maker) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow>=2.6.0->tflite-model-maker) (3.4.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow>=2.6.0->tflite-model-maker) (3.19.6)
# Requirement already satisfied: setuptools in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow>=2.6.0->tflite-model-maker) (80.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow>=2.6.0->tflite-model-maker) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow>=2.6.0->tflite-model-maker) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow>=2.6.0->tflite-model-maker) (1.17.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow>=2.6.0->tflite-model-maker) (2.8.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow>=2.6.0->tflite-model-maker) (2.8.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow>=2.6.0->tflite-model-maker) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow>=2.6.0->tflite-model-maker) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow>=2.6.0->tflite-model-maker) (1.75.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (2.41.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (3.9)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (2.32.5)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (3.1.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (0.45.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (6.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/envs/myenv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/envs/myenv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/envs/myenv/lib/python3.9/site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (0.6.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker) (2.26.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker) (1.63.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official==2.3.0->tflite-model-maker) (1.26.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=2.4.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-cloud-bigquery>=0.31.0->tf-models-official==2.3.0->tflite-model-maker) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=2.0.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-cloud-bigquery>=0.31.0->tf-models-official==2.3.0->tflite-model-maker) (2.7.2)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery>=0.31.0->tf-models-official==2.3.0->tflite-model-maker) (1.48.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from google-resumable-media<3.0dev,>=2.0.0->google-cloud-bigquery>=0.31.0->tf-models-official==2.3.0->tflite-model-maker) (1.7.1)
# Requirement already satisfied: bleach in /usr/local/envs/myenv/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official==2.3.0->tflite-model-maker) (6.2.0)
# Requirement already satisfied: python-slugify in /usr/local/envs/myenv/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official==2.3.0->tflite-model-maker) (8.0.4)
# Requirement already satisfied: text-unidecode in /usr/local/envs/myenv/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official==2.3.0->tflite-model-maker) (1.3)
# Requirement already satisfied: tqdm in /usr/local/envs/myenv/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official==2.3.0->tflite-model-maker) (4.67.1)
# Requirement already satisfied: webencodings in /usr/local/envs/myenv/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official==2.3.0->tflite-model-maker) (0.5.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/envs/myenv/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/envs/myenv/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (3.23.0)
# Requirement already satisfied: attrs in /usr/local/envs/myenv/lib/python3.9/site-packages (from neural-structured-learning>=1.3.1->tflite-model-maker) (25.4.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from numba>=0.53->tflite-model-maker) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from pandas>=0.22.0->tf-models-official==2.3.0->tflite-model-maker) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/envs/myenv/lib/python3.9/site-packages (from pandas>=0.22.0->tf-models-official==2.3.0->tflite-model-maker) (2025.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from pooch>=1.0->librosa==0.8.1->tflite-model-maker) (4.4.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (3.3.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa==0.8.1->tflite-model-maker) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from soundfile>=0.10.2->librosa==0.8.1->tflite-model-maker) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/envs/myenv/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.8.1->tflite-model-maker) (2.23)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow-addons>=0.11.2->tflite-model-maker) (2.13.3)
# Requirement already satisfied: array-record in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker) (0.5.1)
# Requirement already satisfied: click in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker) (8.1.8)
# Requirement already satisfied: dm-tree in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker) (0.1.8)
# Requirement already satisfied: etils>=0.9.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets>=2.1.0->tflite-model-maker) (1.5.2)
# Requirement already satisfied: promise in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker) (2.3)
# Requirement already satisfied: tensorflow-metadata in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker) (1.13.0)
# Requirement already satisfied: toml in /usr/local/envs/myenv/lib/python3.9/site-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker) (0.10.2)
# Requirement already satisfied: fsspec in /usr/local/envs/myenv/lib/python3.9/site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets>=2.1.0->tflite-model-maker) (2025.9.0)
# Requirement already satisfied: importlib_resources in /usr/local/envs/myenv/lib/python3.9/site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets>=2.1.0->tflite-model-maker) (6.5.2)
# Requirement already satisfied: sounddevice>=0.4.4 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-support>=0.4.2->tflite-model-maker) (0.5.2)
# Requirement already satisfied: pybind11>=2.6.0 in /usr/local/envs/myenv/lib/python3.9/site-packages (from tflite-support>=0.4.2->tflite-model-maker) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/envs/myenv/lib/python3.9/site-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow>=2.6.0->tflite-model-maker) (3.0.3)
# /bin/bash: line 10: import: command not found
# /bin/bash: line 11: import: command not found
# /bin/bash: line 13: from: command not found
# /bin/bash: line 14: from: command not found
# /bin/bash: line 15: from: command not found
# /bin/bash: line 16: from: command not found
# /bin/bash: line 17: from: command not found
# /bin/bash: line 19: import: command not found
# /bin/bash: -c: line 20: syntax error near unexpected token `('
# /bin/bash: -c: line 20: `assert tf.__version__.startswith('2')'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipython-input-3445456623.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('shell', '', '\neval "$(conda shell.bash hook)"\n\nconda activate myenv\n\npip install tflite-model-maker\n\n\n# Imports and check that we are using TF2.x\nimport numpy as np\nimport os\n\nfrom tflite_model_maker import configs\nfrom tflite_model_maker import ExportFormat\nfrom tflite_model_maker import model_spec\nfrom tflite_model_maker import text_classifier\nfrom tflite_model_maker.text_classifier import DataLoader\n\nimport tensorflow as tf\nassert tf.__version__.startswith(\'2\')\ntf.get_logger().setLevel(\'ERROR\')\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     274     if line and not cell:
#     275       cell = ' '
# --> 276     return super().run_cell_magic(magic_name, line, cell)
#     277
#     278
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_system_commands.py in _shell_cell_magic(args, cmd)
#     110   result = _run_command(cmd, clear_streamed_output=False)
#     111   if not parsed_args.ignore_errors:
# --> 112     result.check_returncode()
#     113   return result
#     114
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_system_commands.py in check_returncode(self)
#     135   def check_returncode(self):
#     136     if self.returncode:
# --> 137       raise subprocess.CalledProcessError(
#     138           returncode=self.returncode, cmd=self.args, output=self.output
#     139       )
#
# CalledProcessError: Command '
# eval "$(conda shell.bash hook)"
#
# conda activate myenv
#
# pip install tflite-model-maker
#
#
# # Imports and check that we are using TF2.x
# import numpy as np
# import os
#
# from tflite_model_maker import configs
# from tflite_model_maker import ExportFormat
# from tflite_model_maker import model_spec
# from tflite_model_maker import text_classifier
# from tflite_model_maker.text_classifier import DataLoader
#
# import tensorflow as tf
# assert tf.__version__.startswith('2')
# tf.get_logger().setLevel('ERROR')
# ' returned non-zero exit status 2.

# %%
# !pip install tflite-model-maker
# Out:
# Collecting tflite-model-maker
#   Using cached tflite_model_maker-0.4.3-py3-none-any.whl (580 kB)
# Collecting numpy<1.23.4,>=1.17.3
#   Downloading numpy-1.23.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 34.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/site-packages (from tflite-model-maker) (1.17.0)
# Collecting PyYAML>=5.1
#   Downloading pyyaml-6.0.3-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (750 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.8/750.8 kB 73.5 MB/s eta 0:00:00
# Collecting scann==1.2.6
#   Using cached scann-1.2.6-cp39-cp39-manylinux2014_x86_64.whl (10.9 MB)
# Collecting tensorflow-hub<0.13,>=0.7.0
#   Using cached tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
# Collecting absl-py>=0.10.0
#   Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Collecting tensorflow>=2.6.0
#   Downloading tensorflow-2.20.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (620.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 620.4/620.4 MB 1.3 MB/s eta 0:00:00
# Collecting fire>=0.3.1
#   Using cached fire-0.7.1-py3-none-any.whl (115 kB)
# Collecting numba>=0.53
#   Using cached numba-0.60.0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
# Collecting tflite-support>=0.4.2
#   Using cached tflite_support-0.4.4-cp39-cp39-manylinux2014_x86_64.whl (60.8 MB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Using cached urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
# Collecting Cython>=0.29.13
#   Downloading cython-3.1.4-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 13.4 MB/s eta 0:00:00
# Collecting tf-models-official==2.3.0
#   Downloading tf_models_official-2.3.0-py2.py3-none-any.whl (840 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 kB 15.9 MB/s eta 0:00:00
# Collecting matplotlib<3.5.0,>=3.0.3
#   Downloading matplotlib-3.4.3-cp39-cp39-manylinux1_x86_64.whl (10.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 75.9 MB/s eta 0:00:00
# Collecting tensorflow-datasets>=2.1.0
#   Downloading tensorflow_datasets-4.9.3-py3-none-any.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 8.1 MB/s eta 0:00:00
# Collecting librosa==0.8.1
#   Using cached librosa-0.8.1-py3-none-any.whl (203 kB)
# Collecting pillow>=7.0.0
#   Downloading pillow-11.3.0-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 99.7 MB/s eta 0:00:00
# Collecting sentencepiece>=0.1.91
#   Downloading sentencepiece-0.2.1-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 79.9 MB/s eta 0:00:00
# Collecting tensorflow-addons>=0.11.2
#   Downloading tensorflow_addons-0.23.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 55.6 MB/s eta 0:00:00
# Collecting tensorflowjs<3.19.0,>=2.4.0
#   Using cached tensorflowjs-3.18.0-py3-none-any.whl (77 kB)
# Collecting tensorflow-model-optimization>=0.5
#   Using cached tensorflow_model_optimization-0.8.0-py2.py3-none-any.whl (242 kB)
# Collecting neural-structured-learning>=1.3.1
#   Downloading neural_structured_learning-1.4.0-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.6/128.6 kB 22.1 MB/s eta 0:00:00
# Collecting lxml>=4.6.1
#   Downloading lxml-6.0.2-cp39-cp39-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 133.1 MB/s eta 0:00:00
# Collecting audioread>=2.0.0
#   Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Collecting soundfile>=0.10.2
#   Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 24.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/site-packages (from librosa==0.8.1->tflite-model-maker) (25.0)
# Collecting decorator>=3.0.0
#   Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Collecting joblib>=0.14
#   Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.4/308.4 kB 42.9 MB/s eta 0:00:00
# Collecting scikit-learn!=0.19.0,>=0.14.0
#   Downloading scikit_learn-1.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 92.9 MB/s eta 0:00:00
# Collecting scipy>=1.0.0
#   Downloading scipy-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 12.9 MB/s eta 0:00:00
# Collecting pooch>=1.0
#   Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.6/64.6 kB 9.5 MB/s eta 0:00:00
# Collecting resampy>=0.2.2
#   Downloading resampy-0.4.3-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 95.6 MB/s eta 0:00:00
# Collecting tensorflow>=2.6.0
#   Downloading tensorflow-2.8.4-cp39-cp39-manylinux2010_x86_64.whl (498.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.1/498.1 MB 1.3 MB/s eta 0:00:00
# Collecting kaggle>=1.3.9
#   Downloading kaggle-1.7.4.5-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.2/181.2 kB 29.9 MB/s eta 0:00:00
# Collecting tf-slim>=1.1.0
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 kB 47.5 MB/s eta 0:00:00
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting google-cloud-bigquery>=0.31.0
#   Downloading google_cloud_bigquery-3.38.0-py3-none-any.whl (259 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.3/259.3 kB 36.3 MB/s eta 0:00:00
# Collecting psutil>=5.4.3
#   Downloading psutil-7.1.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (291 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.2/291.2 kB 40.8 MB/s eta 0:00:00
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (54.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 MB 9.0 MB/s eta 0:00:00
# Collecting pandas>=0.22.0
#   Downloading pandas-2.3.3-cp39-cp39-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 93.1 MB/s eta 0:00:00
# Collecting gin-config
#   Downloading gin_config-0.5.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 10.2 MB/s eta 0:00:00
# Collecting google-api-python-client>=1.6.7
#   Downloading google_api_python_client-2.184.0-py3-none-any.whl (14.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 104.4 MB/s eta 0:00:00
# Collecting py-cpuinfo>=3.3.0
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Collecting termcolor
#   Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pyparsing>=2.2.1
#   Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.9/113.9 kB 13.8 MB/s eta 0:00:00
# Collecting python-dateutil>=2.7
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 31.5 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.7-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 84.8 MB/s eta 0:00:00
# Collecting attrs
#   Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 10.9 MB/s eta 0:00:00
# Collecting llvmlite<0.44,>=0.43.0dev0
#   Downloading llvmlite-0.43.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 11.9 MB/s eta 0:00:00
# Collecting keras<2.9,>=2.8.0rc0
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 95.1 MB/s eta 0:00:00
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 25.9 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.9,>=2.8
#   Downloading tensorflow_estimator-2.8.0-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 kB 57.0 MB/s eta 0:00:00
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.75.1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 127.0 MB/s eta 0:00:00
# Collecting gast>=0.2.1
#   Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 131.2 MB/s eta 0:00:00
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/site-packages (from tensorflow>=2.6.0->tflite-model-maker) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/site-packages (from tensorflow>=2.6.0->tflite-model-maker) (65.6.3)
# Collecting h5py>=2.9.0
#   Downloading h5py-3.14.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 79.6 MB/s eta 0:00:00
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting libclang>=9.0.1
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 82.1 MB/s eta 0:00:00
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.17.3-cp39-cp39-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.7/81.7 kB 12.8 MB/s eta 0:00:00
# Collecting tensorboard<2.9,>=2.8
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 129.7 MB/s eta 0:00:00
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 12.6 MB/s eta 0:00:00
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 9.5 MB/s eta 0:00:00
# Collecting typeguard<3.0.0,>=2.7
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting array-record
#   Downloading array_record-0.5.1-1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 118.2 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/site-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker) (2.32.5)
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting tensorflow-datasets>=2.1.0
#   Downloading tensorflow_datasets-4.9.2-py3-none-any.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 34.6 MB/s eta 0:00:00
# Collecting etils[enp,epath]>=0.9.0
#   Downloading etils-1.5.2-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 22.6 MB/s eta 0:00:00
# Collecting tensorflow-datasets>=2.1.0
#   Downloading tensorflow_datasets-4.9.1-py3-none-any.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 2.5 MB/s eta 0:00:00
#   Downloading tensorflow_datasets-4.9.0-py3-none-any.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 40.6 MB/s eta 0:00:00
# Collecting tensorflow-metadata
#   Downloading tensorflow_metadata-1.17.2-py3-none-any.whl (31 kB)
# Collecting promise
#   Using cached promise-2.3-py3-none-any.whl
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/site-packages (from tensorflow-datasets>=2.1.0->tflite-model-maker) (4.67.1)
# Collecting dm-tree
#   Downloading dm_tree-0.1.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.0/153.0 kB 23.0 MB/s eta 0:00:00
# Collecting click
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 14.8 MB/s eta 0:00:00
# Collecting absl-py>=0.10.0
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 22.3 MB/s eta 0:00:00
# Collecting packaging>=20.0
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 7.0 MB/s eta 0:00:00
# Collecting pybind11>=2.6.0
#   Downloading pybind11-3.0.1-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.6/293.6 kB 35.1 MB/s eta 0:00:00
# Collecting sounddevice>=0.4.4
#   Downloading sounddevice-0.5.2-py3-none-any.whl (32 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow>=2.6.0->tflite-model-maker) (0.38.4)
# Collecting zipp
#   Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Collecting fsspec
#   Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 32.6 MB/s eta 0:00:00
# Collecting importlib_resources
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting uritemplate<5,>=3.0.1
#   Downloading uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Collecting httplib2<1.0.0,>=0.19.0
#   Downloading httplib2-0.31.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 13.5 MB/s eta 0:00:00
# Collecting google-auth-httplib2<1.0.0,>=0.2.0
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5
#   Downloading google_api_core-2.26.0-py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 kB 28.1 MB/s eta 0:00:00
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0
#   Downloading google_auth-2.41.1-py2.py3-none-any.whl (221 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.3/221.3 kB 35.4 MB/s eta 0:00:00
# Collecting google-cloud-core<3.0.0,>=2.4.1
#   Downloading google_cloud_core-2.4.3-py2.py3-none-any.whl (29 kB)
# Collecting google-cloud-bigquery>=0.31.0
#   Downloading google_cloud_bigquery-3.37.0-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.9/258.9 kB 35.8 MB/s eta 0:00:00
#   Downloading google_cloud_bigquery-3.36.0-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.5/258.5 kB 37.0 MB/s eta 0:00:00
#   Downloading google_cloud_bigquery-3.35.1-py3-none-any.whl (256 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.9/256.9 kB 35.7 MB/s eta 0:00:00
#   Downloading google_cloud_bigquery-3.35.0-py3-none-any.whl (256 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.9/256.9 kB 39.2 MB/s eta 0:00:00
#   Downloading google_cloud_bigquery-3.34.0-py3-none-any.whl (253 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.6/253.6 kB 18.1 MB/s eta 0:00:00
#   Downloading google_cloud_bigquery-3.33.0-py3-none-any.whl (253 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.5/253.5 kB 37.6 MB/s eta 0:00:00
#   Downloading google_cloud_bigquery-3.31.0-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.1/250.1 kB 33.1 MB/s eta 0:00:00
#   Downloading google_cloud_bigquery-3.30.0-py2.py3-none-any.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.9/247.9 kB 35.5 MB/s eta 0:00:00
# Collecting google-resumable-media<3.0dev,>=2.0.0
#   Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 13.9 MB/s eta 0:00:00
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official==2.3.0->tflite-model-maker) (3.7)
# Collecting bleach
#   Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.4/163.4 kB 25.3 MB/s eta 0:00:00
# Collecting text-unidecode
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 13.7 MB/s eta 0:00:00
# Collecting python-slugify
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official==2.3.0->tflite-model-maker) (3.3.2)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official==2.3.0->tflite-model-maker) (2025.10.5)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 46.9 MB/s eta 0:00:00
# Collecting pytz>=2020.1
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 44.7 MB/s eta 0:00:00
# Collecting platformdirs>=2.5.0
#   Downloading platformdirs-4.4.0-py3-none-any.whl (18 kB)
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.9/site-packages (from sounddevice>=0.4.4->tflite-support>=0.4.2->tflite-model-maker) (1.17.1)
# Collecting werkzeug>=0.11.15
#   Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 33.3 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 61.8 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading markdown-3.9-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 18.9 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 77.0 MB/s eta 0:00:00
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (50.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 MB 13.0 MB/s eta 0:00:00
# Collecting tensorflow-metadata
#   Downloading tensorflow_metadata-1.17.1-py3-none-any.whl (31 kB)
#   Downloading tensorflow_metadata-1.17.0-py3-none-any.whl (29 kB)
#   Downloading tensorflow_metadata-1.16.1-py3-none-any.whl (28 kB)
#   Downloading tensorflow_metadata-1.16.0-py3-none-any.whl (28 kB)
#   Downloading tensorflow_metadata-1.15.0-py3-none-any.whl (28 kB)
#   Downloading tensorflow_metadata-1.14.0-py3-none-any.whl (28 kB)
# Collecting googleapis-common-protos<2,>=1.52.0
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.5/294.5 kB 41.4 MB/s eta 0:00:00
# Collecting tensorflow-metadata
#   Downloading tensorflow_metadata-1.13.1-py3-none-any.whl (28 kB)
#   Downloading tensorflow_metadata-1.13.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.3/53.3 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->tflite-support>=0.4.2->tflite-model-maker) (2.23)
# Collecting proto-plus<2.0.0,>=1.22.3
#   Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 7.4 MB/s eta 0:00:00
# Collecting grpcio-status<2.0.0,>=1.33.2
#   Downloading grpcio_status-1.75.1-py3-none-any.whl (14 kB)
# Collecting cachetools<7.0,>=2.0.0
#   Downloading cachetools-6.2.0-py3-none-any.whl (11 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 29.9 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.7.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37 kB)
# Collecting googleapis-common-protos<2,>=1.52.0
#   Downloading googleapis_common_protos-1.69.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.2/293.2 kB 42.6 MB/s eta 0:00:00
#   Downloading googleapis_common_protos-1.69.1-py2.py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.2/293.2 kB 16.3 MB/s eta 0:00:00
#   Downloading googleapis_common_protos-1.69.0-py2.py3-none-any.whl (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.7/169.7 kB 27.6 MB/s eta 0:00:00
#   Downloading googleapis_common_protos-1.68.0-py2.py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.0/165.0 kB 27.2 MB/s eta 0:00:00
#   Downloading googleapis_common_protos-1.67.0-py2.py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.0/165.0 kB 26.7 MB/s eta 0:00:00
#   Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl (221 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.7/221.7 kB 32.4 MB/s eta 0:00:00
#   Downloading googleapis_common_protos-1.65.0-py2.py3-none-any.whl (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.9/220.9 kB 32.4 MB/s eta 0:00:00
#   Downloading googleapis_common_protos-1.64.0-py2.py3-none-any.whl (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.6/220.6 kB 31.7 MB/s eta 0:00:00
#   Downloading googleapis_common_protos-1.63.2-py2.py3-none-any.whl (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.0/220.0 kB 34.2 MB/s eta 0:00:00
#   Downloading googleapis_common_protos-1.63.1-py2.py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.2/229.2 kB 30.9 MB/s eta 0:00:00
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Collecting MarkupSafe>=2.1.1
#   Downloading markupsafe-3.0.3-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (20 kB)
# Collecting grpcio-status<2.0.0,>=1.33.2
#   Downloading grpcio_status-1.75.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.74.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.73.1-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.73.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.72.2-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.72.1-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.71.2-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.71.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.70.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.69.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.68.1-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.68.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.67.1-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.67.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.66.2-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.66.1-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.66.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.65.5-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.65.4-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.65.2-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.65.1-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.64.3-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.64.1-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.64.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.63.2-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.63.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.62.3-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.62.2-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.62.1-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.62.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.61.3-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.60.2-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.60.1-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.60.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.59.5-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.59.3-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.59.2-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.59.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.58.3-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.58.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.57.0-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.56.2-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.56.0-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.55.3-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.54.3-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.54.2-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.54.0-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.53.2-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.53.1-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.53.0-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.51.3-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.51.1-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.50.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.49.1-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.48.2-py3-none-any.whl (14 kB)
# Collecting pyasn1<0.7.0,>=0.6.1
#   Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 13.6 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 22.7 MB/s eta 0:00:00
# Installing collected packages: webencodings, text-unidecode, tensorflow-estimator, tensorboard-plugin-wit, pytz, py-cpuinfo, libclang, keras, gin-config, flatbuffers, dm-tree, dataclasses, zipp, wrapt, urllib3, uritemplate, tzdata, typeguard, toml, threadpoolctl, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, sentencepiece, PyYAML, python-slugify, python-dateutil, pyparsing, pybind11, pyasn1, psutil, protobuf, promise, platformdirs, pillow, opt-einsum, oauthlib, numpy, MarkupSafe, lxml, llvmlite, kiwisolver, joblib, grpcio, google-pasta, google-crc32c, gast, fsspec, etils, decorator, Cython, cycler, click, cachetools, bleach, audioread, attrs, astunparse, absl-py, werkzeug, tf-slim, tensorflow-model-optimization, tensorflow-hub, soundfile, sounddevice, scipy, rsa, pyasn1-modules, proto-plus, pandas, packaging, opencv-python-headless, numba, matplotlib, keras-preprocessing, importlib_resources, importlib-metadata, httplib2, h5py, googleapis-common-protos, google-resumable-media, fire, tflite-support, tensorflow-metadata, tensorflow-addons, scikit-learn, resampy, requests-oauthlib, pooch, neural-structured-learning, markdown, kaggle, grpcio-status, google-auth, librosa, google-auth-oauthlib, google-auth-httplib2, google-api-core, array-record, tensorflow-datasets, tensorboard, google-cloud-core, google-api-python-client, tensorflow, google-cloud-bigquery, tf-models-official, tensorflowjs, scann, tflite-model-maker
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
# Successfully installed Cython-3.1.4 MarkupSafe-3.0.3 PyYAML-6.0.3 absl-py-1.4.0 array-record-0.5.1 astunparse-1.6.3 attrs-25.4.0 audioread-3.0.1 bleach-6.2.0 cachetools-6.2.0 click-8.1.8 cycler-0.12.1 dataclasses-0.6 decorator-5.2.1 dm-tree-0.1.8 etils-1.5.2 fire-0.7.1 flatbuffers-25.9.23 fsspec-2025.9.0 gast-0.6.0 gin-config-0.5.0 google-api-core-2.26.0 google-api-python-client-2.184.0 google-auth-2.41.1 google-auth-httplib2-0.2.0 google-auth-oauthlib-0.4.6 google-cloud-bigquery-3.30.0 google-cloud-core-2.4.3 google-crc32c-1.7.1 google-pasta-0.2.0 google-resumable-media-2.7.2 googleapis-common-protos-1.63.1 grpcio-1.75.1 grpcio-status-1.48.2 h5py-3.14.0 httplib2-0.31.0 importlib-metadata-8.7.0 importlib_resources-6.5.2 joblib-1.5.2 kaggle-1.7.4.5 keras-2.8.0 keras-preprocessing-1.1.2 kiwisolver-1.4.7 libclang-18.1.1 librosa-0.8.1 llvmlite-0.43.0 lxml-6.0.2 markdown-3.9 matplotlib-3.4.3 neural-structured-learning-1.4.0 numba-0.60.0 numpy-1.23.3 oauthlib-3.3.1 opencv-python-headless-4.11.0.86 opt-einsum-3.4.0 packaging-20.9 pandas-2.3.3 pillow-11.3.0 platformdirs-4.4.0 pooch-1.8.2 promise-2.3 proto-plus-1.26.1 protobuf-3.19.6 psutil-7.1.0 py-cpuinfo-9.0.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 pybind11-3.0.1 pyparsing-3.2.5 python-dateutil-2.9.0.post0 python-slugify-8.0.4 pytz-2025.2 requests-oauthlib-2.0.0 resampy-0.4.3 rsa-4.9.1 scann-1.2.6 scikit-learn-1.6.1 scipy-1.13.1 sentencepiece-0.2.1 sounddevice-0.5.2 soundfile-0.13.1 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.4 tensorflow-addons-0.23.0 tensorflow-datasets-4.9.0 tensorflow-estimator-2.8.0 tensorflow-hub-0.12.0 tensorflow-io-gcs-filesystem-0.37.1 tensorflow-metadata-1.13.0 tensorflow-model-optimization-0.8.0 tensorflowjs-3.18.0 termcolor-3.1.0 text-unidecode-1.3 tf-models-official-2.3.0 tf-slim-1.1.0 tflite-model-maker-0.4.3 tflite-support-0.4.4 threadpoolctl-3.6.0 toml-0.10.2 typeguard-2.13.3 tzdata-2025.2 uritemplate-4.2.0 urllib3-1.25.11 webencodings-0.5.1 werkzeug-3.1.3 wrapt-1.17.3 zipp-3.23.0

# %%
# Imports and check that we are using TF2.x
import numpy as np
import os

from tflite_model_maker import configs
from tflite_model_maker import ExportFormat
from tflite_model_maker import model_spec
from tflite_model_maker import text_classifier
from tflite_model_maker.text_classifier import DataLoader

import tensorflow as tf
assert tf.__version__.startswith('2')
tf.get_logger().setLevel('ERROR')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-672655383.py in <cell line: 0>()
#       3 import os
#       4
# ----> 5 from tflite_model_maker import configs
#       6 from tflite_model_maker import ExportFormat
#       7 from tflite_model_maker import model_spec
#
# ModuleNotFoundError: No module named 'tflite_model_maker'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Download the dataset as a CSV and store as data_file
data_file = tf.keras.utils.get_file(fname='comment-spam.csv', origin='https://storage.googleapis.com/laurencemoroney-blog.appspot.com/lmblog_comments.csv', extract=False)

# %%
# Use a model spec from model maker. Options are 'mobilebert_classifier', 'bert_classifier' and 'average_word_vec'
# The first 2 use the BERT model, which is accurate, but larger and slower to train
# Average Word Vec is kinda like transfer learning where there are pre-trained word weights
# and dictionaries
spec = model_spec.get('average_word_vec')
spec.num_words = 2000
spec.seq_len = 20
spec.wordvec_dim = 7

# %%
# Load the CSV using DataLoader.from_csv to make the training_data
data = DataLoader.from_csv(
      filename=data_file,
      text_column='commenttext',
      label_column='spam',
      model_spec=spec,
      delimiter=',',
      shuffle=True,
      is_training=True)

train_data, test_data = data.split(0.9)

# %%
# Build the model
model = text_classifier.create(train_data, model_spec=spec, epochs=50, validation_data=test_data)

# %%
loss, accuracy = model.evaluate(train_data)

# %%
# This will export to TFLite format with the model only.
# if you see a .json file in this directory, it is NOT the JSON model for TFJS
# See below for how to generate that.
# Please note that if you run this cell to create the tflite model then the
# export to TFJS will fail. You'll need to rerun the model training first
model.export(export_dir='/mm_spam')
# If you want the labels and the vocab, for example for iOS, you can use this
model.export(export_dir='/mm_spam/', export_format=[ExportFormat.LABEL, ExportFormat.VOCAB])

# You can find your files in colab by clicking the 'folder' tab to the left of
# this code window, and then navigating 'up' a directory to find the root
# directory listing -- and from there you should see /mm_spam/

# %%
# Use this section for export to TFJS
# Please note that if you run the above cell to create the tflite model then the
# export to TFJS will fail. You'll need to rerun the model training first
model.export(export_dir="/mm_js/", export_format=[ExportFormat.TFJS, ExportFormat.LABEL, ExportFormat.VOCAB])

# %%
# Optional extra
# You can use this cell to export details for projector.tensorflow.org
# Where you can explore the embeddings that were learned for this dataset
embeddings = model.model.layers[0]
weights = embeddings.get_weights()[0]
tokenizer = model.model_spec.vocab

import io

out_v = io.open('vecs.tsv', 'w', encoding='utf-8')
out_m = io.open('meta.tsv', 'w', encoding='utf-8')
for word in tokenizer:
  #word = tokenizer.decode([word_num])
  value = tokenizer[word]
  embeddings = weights[value]
  out_m.write(word + "\n")
  out_v.write('\t'.join([str(x) for x in embeddings]) + "\n")
out_v.close()
out_m.close()


try:
  from google.colab import files
except ImportError:
  pass
else:
  files.download('vecs.tsv')
  files.download('meta.tsv')
